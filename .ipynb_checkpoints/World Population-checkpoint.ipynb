# %% [markdown]
# # Source
# The sourcefor this data can be found on https://population.un.org/wpp/

# %%
#get the data by importing it.
import requests
dls = "https://population.un.org/wpp/Download/Files/1_Indicators%20(Standard)/EXCEL_FILES/1_General/WPP2022_GEN_F01_DEMOGRAPHIC_INDICATORS_REV1.xlsx"
resp = requests.get(dls)

output = open('WPP2022_GEN_F01_DEMOGRAPHIC_INDICATORS_REV1.xlsx', 'wb')
output.write(resp.content)
output.close()

# %%
output
# Out:
# <_io.BufferedWriter name='WPP2022_GEN_F01_DEMOGRAPHIC_INDICATORS_REV1.xlsx'>

# %%
import pandas as pd
pandasDF = pd.read_excel(io=file-like, engine='openpyxl', sheet_name = 'WPP2022_GEN_F01_DEMOGRAPHIC_INDICATORS_REV1.xlsx')
pandasDF
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/06/tstl7m5d0dg0v7h2y2f29f800000gp/T/ipykernel_46343/3060267429.py in <module>
#       1 import pandas as pd
# ----> 2 pandasDF = pd.read_excel(io=file-like, engine='openpyxl', sheet_name = 'WPP2022_GEN_F01_DEMOGRAPHIC_INDICATORS_REV1.xlsx')
#       3 pandasDF
#
# NameError: name 'file' is not defined

# %%
pd.read_excel(open('WPP2022_GEN_F01_DEMOGRAPHIC_INDICATORS_REV1.xlsx', 'rb'),
              sheet_name='Estimates',header=16)#.iloc[15:]
# Out:
#        Index    Variant Region, subregion, country or area * Notes  \
# 0          1  Estimates                                WORLD   NaN
# 1          2  Estimates                                WORLD   NaN
# 2          3  Estimates                                WORLD   NaN
# 3          4  Estimates                                WORLD   NaN
# 4          5  Estimates                                WORLD   NaN
# ...      ...        ...                                  ...   ...
# 20591  20592  Estimates            Wallis and Futuna Islands     2
# 20592  20593  Estimates            Wallis and Futuna Islands     2
# 20593  20594  Estimates            Wallis and Futuna Islands     2
# 20594  20595  Estimates            Wallis and Futuna Islands     2
# 20595  20596  Estimates            Wallis and Futuna Islands     2
#
#        Location code ISO3 Alpha-code ISO2 Alpha-code  SDMX code**  \
# 0                900             NaN             NaN          1.0
# 1                900             NaN             NaN          1.0
# 2                900             NaN             NaN          1.0
# 3                900             NaN             NaN          1.0
# 4                900             NaN             NaN          1.0
# ...              ...             ...             ...          ...
# 20591            876             WLF              WF        876.0
# 20592            876             WLF              WF        876.0
# 20593            876             WLF              WF        876.0
# 20594            876             WLF              WF        876.0
# 20595            876             WLF              WF        876.0
#
#                Type  Parent code  ...  \
# 0             World            0  ...
# 1             World            0  ...
# 2             World            0  ...
# 3             World            0  ...
# 4             World            0  ...
# ...             ...          ...  ...
# 20591  Country/Area          957  ...
# 20592  Country/Area          957  ...
# 20593  Country/Area          957  ...
# 20594  Country/Area          957  ...
# 20595  Country/Area          957  ...
#
#        Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births)  \
# 0                                                 580.75
# 1                                                566.728
# 2                                                546.317
# 3                                                535.829
# 4                                                523.124
# ...                                                  ...
# 20591                                             92.066
# 20592                                             99.196
# 20593                                             77.781
# 20594                                             85.608
# 20595                                             89.321
#
#       Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births)  \
# 0                                                 498.04
# 1                                                490.199
# 2                                                477.264
# 3                                                469.532
# 4                                                458.484
# ...                                                  ...
# 20591                                            102.718
# 20592                                             89.345
# 20593                                             80.136
# 20594                                             86.364
# 20595                                              84.68
#
#       Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15)  \
# 0                                                240.316
# 1                                                231.177
# 2                                                218.674
# 3                                                212.872
# 4                                                205.762
# ...                                                  ...
# 20591                                             30.643
# 20592                                             29.201
# 20593                                             24.304
# 20594                                             26.572
# 20595                                             25.848
#
#       Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15)  \
# 0                                                271.625
# 1                                                 258.09
# 2                                                240.034
# 3                                                232.602
# 4                                                 224.05
# ...                                                  ...
# 20591                                             26.781
# 20592                                             29.159
# 20593                                             22.291
# 20594                                             24.691
# 20595                                             24.836
#
#       Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15)  \
# 0                                                208.192
# 1                                                 203.78
# 2                                                197.142
# 3                                                193.049
# 4                                                187.444
# ...                                                  ...
# 20591                                             33.892
# 20592                                              29.17
# 20593                                             25.981
# 20594                                             28.127
# 20595                                             26.644
#
#       Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15)  \
# 0                                                378.697
# 1                                                368.319
# 2                                                353.055
# 3                                                345.083
# 4                                                335.442
# ...                                                  ...
# 20591                                             82.852
# 20592                                             79.633
# 20593                                             66.639
# 20594                                              72.73
# 20595                                             74.207
#
#       Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15)  \
# 0                                                430.259
# 1                                                415.836
# 2                                                395.533
# 3                                                385.843
# 4                                                374.658
# ...                                                  ...
# 20591                                             82.197
# 20592                                             88.556
# 20593                                             69.324
# 20594                                             76.411
# 20595                                             80.373
#
#       Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15)  \
# 0                                                324.931
# 1                                                319.336
# 2                                                 309.91
# 3                                                303.905
# 4                                                295.994
# ...                                                  ...
# 20591                                              83.32
# 20592                                             72.163
# 20593                                             64.496
# 20594                                             69.685
# 20595                                             68.905
#
#       Net Number of Migrants (thousands)  \
# 0                                      0
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      0
# ...                                  ...
# 20591                             -0.201
# 20592                             -0.171
# 20593                             -0.171
# 20594                             -0.083
# 20595                             -0.083
#
#       Net Migration Rate (per 1,000 population)
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ...                                         ...
# 20591                                   -16.706
# 20592                                   -14.368
# 20593                                   -14.489
# 20594                                    -7.096
# 20595                                    -7.112
#
# [20596 rows x 65 columns]

# %%
import yaml
with open('metadata/estimate.yaml', 'r') as file:
    prime_service = yaml.safe_load(file)
# Out:
# ---------------------------------------------------------------------------
# ScannerError                              Traceback (most recent call last)
# /var/folders/06/tstl7m5d0dg0v7h2y2f29f800000gp/T/ipykernel_46343/3889629339.py in <module>
#       1 import yaml
#       2 with open('metadata/estimate.yaml', 'r') as file:
# ----> 3     prime_service = yaml.safe_load(file)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/yaml/__init__.py in safe_load(stream)
#     123     to be safe for untrusted input.
#     124     """
# --> 125     return load(stream, SafeLoader)
#     126
#     127 def safe_load_all(stream):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/yaml/__init__.py in load(stream, Loader)
#      79     loader = Loader(stream)
#      80     try:
# ---> 81         return loader.get_single_data()
#      82     finally:
#      83         loader.dispose()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/yaml/constructor.py in get_single_data(self)
#      47     def get_single_data(self):
#      48         # Ensure that the stream contains a single document and construct it.
# ---> 49         node = self.get_single_node()
#      50         if node is not None:
#      51             return self.construct_document(node)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/yaml/composer.py in get_single_node(self)
#      34         document = None
#      35         if not self.check_event(StreamEndEvent):
# ---> 36             document = self.compose_document()
#      37
#      38         # Ensure that the stream contains no more documents.
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/yaml/composer.py in compose_document(self)
#      53
#      54         # Compose the root node.
# ---> 55         node = self.compose_node(None, None)
#      56
#      57         # Drop the DOCUMENT-END event.
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/yaml/composer.py in compose_node(self, parent, index)
#      82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
# ---> 84             node = self.compose_mapping_node(anchor)
#      85         self.ascend_resolver()
#      86         return node
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/yaml/composer.py in compose_mapping_node(self, anchor)
#     131             #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132             #            "found duplicate key", key_event.start_mark)
# --> 133             item_value = self.compose_node(node, item_key)
#     134             #node.value[item_key] = item_value
#     135             node.value.append((item_key, item_value))
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/yaml/composer.py in compose_node(self, parent, index)
#      80             node = self.compose_scalar_node(anchor)
#      81         elif self.check_event(SequenceStartEvent):
# ---> 82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
#      84             node = self.compose_mapping_node(anchor)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/yaml/composer.py in compose_sequence_node(self, anchor)
#     109         index = 0
#     110         while not self.check_event(SequenceEndEvent):
# --> 111             node.value.append(self.compose_node(node, index))
#     112             index += 1
#     113         end_event = self.get_event()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/yaml/composer.py in compose_node(self, parent, index)
#      82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
# ---> 84             node = self.compose_mapping_node(anchor)
#      85         self.ascend_resolver()
#      86         return node
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/yaml/composer.py in compose_mapping_node(self, anchor)
#     131             #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132             #            "found duplicate key", key_event.start_mark)
# --> 133             item_value = self.compose_node(node, item_key)
#     134             #node.value[item_key] = item_value
#     135             node.value.append((item_key, item_value))
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/yaml/composer.py in compose_node(self, parent, index)
#      62
#      63     def compose_node(self, parent, index):
# ---> 64         if self.check_event(AliasEvent):
#      65             event = self.get_event()
#      66             anchor = event.anchor
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/yaml/parser.py in check_event(self, *choices)
#      96         if self.current_event is None:
#      97             if self.state:
# ---> 98                 self.current_event = self.state()
#      99         if self.current_event is not None:
#     100             if not choices:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/yaml/parser.py in parse_block_mapping_value(self)
#     447         if self.check_token(ValueToken):
#     448             token = self.get_token()
# --> 449             if not self.check_token(KeyToken, ValueToken, BlockEndToken):
#     450                 self.states.append(self.parse_block_mapping_key)
#     451                 return self.parse_block_node_or_indentless_sequence()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/yaml/scanner.py in check_token(self, *choices)
#     114         # Check if the next token is one of the given types.
#     115         while self.need_more_tokens():
# --> 116             self.fetch_more_tokens()
#     117         if self.tokens:
#     118             if not choices:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/yaml/scanner.py in fetch_more_tokens(self)
#     258         raise ScannerError("while scanning for the next token", None,
#     259                 "found character %r that cannot start any token" % ch,
# --> 260                 self.get_mark())
#     261
#     262     # Simple keys treatment.
#
# ScannerError: while scanning for the next token
# found character '\t' that cannot start any token
#   in "metadata/estimate.yaml", line 5, column 12
